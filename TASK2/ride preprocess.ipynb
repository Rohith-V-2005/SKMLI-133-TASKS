# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
pip install openpyxl==3.0.10
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: C:\Users\ROHITH\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
data = pd.read_excel('Desktop/internship/New folder/ct_rr.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = pd.read_excel('Desktop/internship/New folder/ct_rr.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
df = data.resample('h', on='ts').size().reset_index(name='ride_requests')
df
# Out:
#                       ts  ride_requests
# 0    2018-04-07 01:00:00             20
# 1    2018-04-07 02:00:00              5
# 2    2018-04-07 03:00:00              1
# 3    2018-04-07 04:00:00              0
# 4    2018-04-07 05:00:00              6
# ...                  ...            ...
# 2922 2018-08-06 19:00:00            123
# 2923 2018-08-06 20:00:00            178
# 2924 2018-08-06 21:00:00            141
# 2925 2018-08-06 22:00:00             77
# 2926 2018-08-06 23:00:00             23
#
# [2927 rows x 2 columns]

# %%
df["date"] = df['ts'].dt.date
data['day_of_week'] = data['ts'].dt.dayofweek

# %%
from datetime import datetime
import calendar
def weekend_or_weekday(year, month, day):
  d = datetime(int(year), int(month), int(day))
  if d.weekday() > 4:
    return 0
  else:
    return 1
df['weekday'] = df.apply(lambda x:weekend_or_weekday(x['year'], x['month'],x['day']), axis=1)
df.head()
# Out:
#                    ts  ride_requests        date      time  year  month  day  \
# 0 2018-04-07 01:00:00             20  2018-04-07  01:00:00  2018      4    7
# 1 2018-04-07 02:00:00              5  2018-04-07  02:00:00  2018      4    7
# 2 2018-04-07 03:00:00              1  2018-04-07  03:00:00  2018      4    7
# 3 2018-04-07 04:00:00              0  2018-04-07  04:00:00  2018      4    7
# 4 2018-04-07 05:00:00              6  2018-04-07  05:00:00  2018      4    7
#
#    weekday  am_or_pm  holidays
# 0        0         0         0
# 1        0         0         0
# 2        0         0         0
# 3        0         0         0
# 4        0         0         0

# %%
from datetime import date
import holidays
def is_holiday(x):
	india_holidays = holidays.country_holidays('IN')
	if india_holidays.get(x):
		return 1
	else:
		return 0
df['holidays'] = df['date'].apply(is_holiday)
df.head()
# Out:
#                    ts  ride_requests        date      time  year  month  day  \
# 0 2018-04-07 01:00:00             20  2018-04-07  01:00:00  2018      4    7
# 1 2018-04-07 02:00:00              5  2018-04-07  02:00:00  2018      4    7
# 2 2018-04-07 03:00:00              1  2018-04-07  03:00:00  2018      4    7
# 3 2018-04-07 04:00:00              0  2018-04-07  04:00:00  2018      4    7
# 4 2018-04-07 05:00:00              6  2018-04-07  05:00:00  2018      4    7
#
#    weekday  am_or_pm  holidays
# 0        0         0         0
# 1        0         0         0
# 2        0         0         0
# 3        0         0         0
# 4        0         0         0

# %%
# Write the DataFrame to an Excel file
df.to_excel('/content/drive/MyDrive/updated_dataset.xlsx', index=False)
