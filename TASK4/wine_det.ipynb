# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
wine = pd.read_csv("/content/drive/MyDrive/Wineqlty.csv")

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
wine.drop(['Id'],axis=1,inplace=True)

# %%
wine.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
print(wine.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Define the general range for each feature
general_ranges = {
    'fixed acidity': (4.0, 15.0),
    'volatile acidity': (0.12, 1.20),
    'citric acid': (0.00, 1.00),
    'residual sugar': (0.9, 15.5),
    'chlorides': (0.012, 0.200),
    'free sulfur dioxide': (1, 50),
    'total sulfur dioxide': (6, 150),
    'density': (0.990, 1.003),
    'pH': (2.9, 4.0),
    'sulphates': (0.33, 1.5),
    'alcohol': (8.0, 14.5),
    'quality': (3, 8)
}

def remove_outside_general_range(df, ranges):
    for feature, (min_val, max_val) in ranges.items():
        df = df[(df[feature] >= min_val) & (df[feature] <= max_val)]
    return df

# Remove data outside the general range
cleaned_wine_data = remove_outside_general_range(wine, general_ranges)
cleaned_wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1084.000000       1084.000000  1084.000000      1084.00000
# mean        8.274908          0.529488     0.260452         2.48095
# std         1.699470          0.174021     0.191223         1.15954
# min         4.600000          0.120000     0.000000         1.20000
# 25%         7.100000          0.390000     0.090000         1.90000
# 50%         7.900000          0.520000     0.240000         2.20000
# 75%         9.100000          0.640000     0.410000         2.60000
# max        15.000000          1.180000     0.790000        15.50000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1084.000000          1084.000000           1084.000000  1084.000000
# mean      0.080555            15.212177             44.649446     0.996693
# std       0.019609             9.410766             30.343810     0.001855
# ...

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
def filter_good_quality_wine(df):
    conditions = (
        (df['fixed acidity'] >= 5.0) & (df['fixed acidity'] <= 10.0) &
        (df['volatile acidity'] <= 0.6) &
        (df['citric acid'] >= 0.2) & (df['citric acid'] <= 0.5) &
        (df['residual sugar'] <= 4.0) &
        (df['chlorides'] <= 0.08) &
        (df['free sulfur dioxide'] <= 35) &
        (df['total sulfur dioxide'] <= 100) &
        (df['density'] >= 0.990) & (df['density'] <= 0.998) &
        (df['pH'] >= 3.0) & (df['pH'] <= 3.4) &
        (df['sulphates'] >= 0.4) & (df['sulphates'] <= 0.65) &
        (df['alcohol'] >= 10.0) & (df['alcohol'] <= 13.5) &
        (df['quality'] >= 6)
    )
    df['good']=conditions.astype(int)
    return df

# Filter good quality wines
wine= filter_good_quality_wine(wine)

# %%
wine.good.value_counts()
# Out:
# good
# 0    1110
# 1      33
# Name: count, dtype: int64

# %%
X = wine.drop(['quality','good'], axis = 1)
Y = wine['good']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score,classification_report
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
print(classification_report(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.967930029154519
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       332
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.97       343
#    macro avg       0.74      0.54      0.57       343
# weighted avg       0.96      0.97      0.96       343

# %%
test_case_df = pd.DataFrame({
    'fixed acidity': [6.0],
    'volatile acidity': [0.5],
    'citric acid': [0.3],
    'residual sugar': [3.0],
    'chlorides': [0.06],
    'free sulfur dioxide': [30],
    'total sulfur dioxide': [95],
    'density': [0.995],
    'pH': [3.2],
    'sulphates': [0.5],
    'alcohol': [12.0]
})
y_hat=model2.predict(test_case_df)
print(y_hat)
# Out:
# [0]

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Split the data with stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42, stratify=Y
)

# Apply SMOTE to the training set
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Train the model
model = RandomForestClassifier(random_state=42)
model.fit(X_train_resampled, y_train_resampled)

# Predict and evaluate
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       333
#            1       1.00      0.50      0.67        10
#
#     accuracy                           0.99       343
#    macro avg       0.99      0.75      0.83       343
# weighted avg       0.99      0.99      0.98       343
